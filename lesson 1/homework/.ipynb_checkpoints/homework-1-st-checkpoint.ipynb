# %% [markdown]
# # Домашнее задание 1. Сбор данных

# %% [markdown]
# При решении реальных задач мы почти никогда не имеем дело с "хорошими" исходными данными, уже подготовленными для обработки и анализа. Как правило на входе имеются неструкткрированные данные в "грязном" виде, например необработанные тексты, изображения или аудио файлы. Иногда нет даже этого, и данные приходится собирать из разных доступных источников: разнообразных баз данных, внешних сервисов и даже электронных таблиц. После того, как данные получены, их унифицируют, очищают от шума, преобразовывают в нужный вид и сохраняют для дальнейшего анализа. В одном из традиционных подходов к [Data Mining](http://www.wikiwand.com/en/Online_analytical_processing) этот процесс называется Extract-Transform-Load ([ETL](http://www.wikiwand.com/en/Extract,_transform,_load)).
#
# Цель этого задания собрать первые данные о пользователях из обучающей выборки и провести простейший качественный анализ. В ходе решения будут использованы:
# 1. [numpy](http://www.numpy.org/) -- библиотека для работы с многомерными массивами
# 2. [pandas](http://pandas.pydata.org/) -- библиотека, позволяющая удобно работать с различными типами данных
# 3. [requests](http://docs.python-requests.org/en/latest/) -- библиотека, которую можно использовать для вызова HTTP запросов
# 4. [python-twitter](https://github.com/bear/python-twitter/tree/master/twitter) -- обертка для Twitter API
# 5. [matplotlib](http://matplotlib.org/) -- библиотека для рисования графиков в python
#
# Первым делом импортируем необходимые библиотеки и убеждаемся, что все установлено.

# %%
import pandas as pd
import numpy as np
import pylab as pl
import mpl_toolkits.basemap as bm
import twitter
import requests
import datetime
import dateutil
import csv
import os
import json
import time

# Plotting config
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Чтение исходных данных из файла

# %% [markdown]
# Считываем исходные данные из файла в data frame библиотеки pandas. Полученный data frame должен иметь целочисленный ключ и две колонки:
# 1. uid -- идентификатор пользователя
# 2. cat -- числовой номер класса

# %%
TRAINING_SET_PATH = "train.csv"
TESTING_SET_PATH = "test.csv"
df_users_train = pd.read_csv(TRAINING_SET_PATH, sep=",", header=0)
df_users_ex = pd.read_csv(TESTING_SET_PATH, sep=",", header=0)
df_users_ex['cls'] = None
df_users = pd.concat([df_users_train, df_users_ex])
print df_users.head()
df_users.count()
# Out:
#           uid  cls
# 0   202388889  1.0
# 1  1392518336  0.0
# 2   361208576  1.0
# 3  1535215357  1.0
# 4  4396196375  1.0
# uid    11947
# cls     7199
# dtype: int64

# %% [markdown]
# Построим распределение целевой переменной. Требуется получить [barchart](http://www.wikiwand.com/en/Bar_chart), в котором высота столбика, соответствующего каждому из классов, пропорциональна количеству пользователей этого класса. По горизонтальной оси отложены классы (positive, negative), а по вертикальной -- количество пользователей.

# %%
# Compute the distribution of the target variable
counts, bins = np.histogram(df_users_train["cls"], bins=[0,1,2])

# Plot the distribution
pl.figure(figsize=(6,6))
pl.bar(bins[:-1], counts, width=0.5, alpha=0.4)
pl.xticks(bins[:-1] + 0.3, ["negative", "positive"])
pl.xlim(bins[0] - 0.5, bins[-1])
pl.ylabel("Number of users")
pl.title("Target variable distribution")
pl.show()

# %% [markdown]
# ## Сбор данных

# %% [markdown]
# Для того чтобы разработать модель, которая предсказывает значение целевой переменной для произвольного пользователя, недостаточно знать только значения идентификаторов пользоватей. Причина в том, что _user_id_ для пользователя никак не зависит от целевой переменной -- идентификатор генерируется на основании времени регистрации, сервера, обрабатывающего запрос, и номера пользователя ([подробности](https://dev.twitter.com/overview/api/twitter-ids-json-and-snowflake)).
#
# Поэтому нам потребуется загрузить дополнительную информацию о каждом пользователе, иначе говоря провести сбор данных (data collection). Наиболее важную информацию можно загрузить из [Twitter](https://dev.twitter.com/rest/public) [API](http://www.wikiwand.com/en/Representational_state_transfer). При желании можно воспользоваться и другими источниками -- об этом ниже.
#
# Для того, чтобы получить доступ к API прежде всего необходимо зарегистрироваться в Twitter в качестве разработчика и создать свое [приложение](https://apps.twitter.com/). После создания приложения будет доступен набор ключей, которые мы будем использовать для аутентификации. Эти ключи необходимо скопировать в соответствующие константы ниже. Подробнее о том, как работает аутентификация в Twitter API можно почитать [по ссылке](https://dev.twitter.com/oauth/application-only), хотя это нужно скорее для ознакомления: библиотека обращения с API позаботится о механизме аутентификации за нас.

# %%
config_file_name = 'config_file'

if os.path.exists(config_file_name):
    with open(config_file_name) as f:
        for line in f:
            try:
                config = json.loads(line)
            except:
                continue

                
CONSUMER_KEY = config['CONSUMER_KEY']
CONSUMER_SECRET = config['CONSUMER_SECRET']

ACCESS_TOKEN_KEY = config['ACCESS_TOKEN_KEY']
ACCESS_TOKEN_SECRET = config['ACCESS_TOKEN_SECRET']

api = twitter.Api(consumer_key=CONSUMER_KEY, 
                  consumer_secret=CONSUMER_SECRET, 
                  access_token_key=ACCESS_TOKEN_KEY, 
                  access_token_secret=ACCESS_TOKEN_SECRET)

# %% [markdown]
# Twitter API предоставляет информацию о местонахождении пользователя, но эта информация представлена в текстовом виде, например так:
# ```
# "location": "San Francisco, CA"
# ```
# Такие текстовый описания не слишком удобны для анализа, поэтому наша цель -- получить более структурированную информацию, такую как географические координаты, страна, город и т.д. Для этого удобно использовать геоинформационный сервис, например [GeoNames](http://www.geonames.org/export/web-services.html). Для его использования также необходимо зарегистрироваться, подтвердить регистрацию и включить поддержку API. После этого можно будет посылать запросы для нахождения нужной информации. Например на запрос
# ```
# http://api.geonames.org/search?q="San Francisco, CA"&maxRows=10&username=demo
# ```
# возвращается результат,
# ```javascript
# {
#     "totalResultsCount": 2112,
#     "geonames": [
#         {
#             "countryId": "6252001",
#             "adminCode1": "CA",
#             "countryName": "United States",
#             "fclName": "city, village,...",
#             "countryCode": "US",
#             "lng": "-122.41942",
#             "fcodeName": "seat of a second-order administrative division",
#             "toponymName": "San Francisco",
#             "fcl": "P",
#             "name": "San Francisco",
#             "fcode": "PPLA2",
#             "geonameId": 5391959,
#             "lat": "37.77493",
#             "adminName1": "California",
#             "population": 805235
#         },
#         {
#             "countryId": "6252001",
#             "adminCode1": "CA",
#             "countryName": "United States",
#             "fclName": "spot, building, farm",
#             "countryCode": "US",
#             "lng": "-122.3758",
#             "fcodeName": "airport",
#             "toponymName": "San Francisco International Airport",
#             "fcl": "S",
#             "name": "San Francisco International Airport",
#             "fcode": "AIRP",
#             "geonameId": 5391989,
#             "lat": "37.61882",
#             "adminName1": "California",
#             "population": 0
#         }
#     ]
# }
# ```
# из которого легко извлечь нужную информацию.
#
# **Замечание: для запросов необходимо использовать своего пользователя, кроме того количество запросов ограничено 30тыс в день**.
#
# Первым делом нам понадобится функция, которая возвращает информацию о местоположении для данного текстового запроса. Требуется реализовать функцию get_coordinates_by_location, принимающую на вход строку с местоположением и возвращает кортеж вида (долгота, широта, город).

# %%
GEO_USER_NAME = "a1a2a4a8"

def get_coordinates_by_location(location):
    try:
        location = requests.get('http://api.geonames.org/searchJSON?q={0}&maxRows=10&username={1}'.format(location.encode('utf-8'), GEO_USER_NAME)).json()
    except error:
        print error.message
        return (None, None, None)
    if "geonames" in location: 
        for coord in location["geonames"]:
            if "lat" in coord and coord["lat"] != "0" and "lng" in coord and coord["lng"] != "0":
                return (
                    float(coord["lat"]), 
                    float(coord["lng"]), 
                    coord["countryName"] if "countryName" in coord else None
                )
    return (None, None, None)
#get_coordinates_by_location(api.GetUser(202388889).location)

# %% [markdown]
# Следующий шаг -- вызов Twitter API для сбора данных и сохранения их в data frame. После чего data frame c собранными данными совмещается с data frame, содержащим данные исходной обучающей выборки.
#
# В этой части задания нужно реализовать функцию `get_user_records`, которая принимает на вход прочитанный из файла `data frame` и возвращает список словарей, каждый из которых представляет данные одного пользователя. Для того, чтобы получить из объекта класса [`User`](https://github.com/bear/python-twitter/blob/master/twitter/user.py) словарь в правильном формате, нужно использовать функцию `twitter_user_to_dataframe_record` (4 балла).
#
# Так как скрипт работает существенное время, будем сохранять промежуточный результат.

# %%
ts_parser = lambda date_str: dateutil.parser.parse(date_str) if pd.notnull(date_str) else None

user_records = []
tmp_file_name = 'tmp_user_records'
if os.path.exists(tmp_file_name):
    with open(tmp_file_name) as f:
        for line in f:
            try:
                user_records.append(json.loads(line))
            except:
                continue

processed_users = set()
for r in user_records:
    processed_users.add(r['uid'])
    
f = open(tmp_file_name, 'a')
            
def twitter_user_to_dataframe_record(user):
    dt = ts_parser(user.created_at)
    record = {
        "uid": user.id,
        "name": user.name,
        "screen_name": user.screen_name,        
        "created_at": dt.strftime("%Y-%m") if dt else dt,        
        "followers_count": user.followers_count,
        "friends_count": user.friends_count,
        "statuses_count": user.statuses_count,
        "favourites_count": user.favourites_count,
        "listed_count": user.listed_count,
        "verified": user.verified
    }
    
    if user.description is not None and user.description.strip() != "":
        record["description"] = user.description
        
    if user.location is not None and user.location.strip() != "":
        record["location"] = user.location
        record["lat"], record["lon"], record["country"] = get_coordinates_by_location(user.location)
    
    return record

def get_user_records(df):
    users = []
    queue = []
    for i, user_id in enumerate(df['uid'].values):
        if user_id in processed_users:
            print "[{0}] User {1} already loaded".format(i, user_id)
            continue
        else:
            queue += [user_id]
            print "[{0}] User {1} was added to queue (total count = {2})".format(i, user_id, len(queue))
            
            if len(queue) >= 100:
                try:
                    new_users = api.UsersLookup(user_id = queue)
                except:
                    print "Getting users error"
                    break
                
                print type(new_users)
                for i, user in enumerate(new_users):
                    if type(user) is twitter.models.User:
                        print "User {0} reading from list".format(i)
                        current_user = twitter_user_to_dataframe_record(user)
                        new_users += [current_user]
                        f.write(json.dumps(current_user) + '\n')
                        f.flush()
                
                queue = []
                users += new_users
            
    f.close()
    return users

user_records += get_user_records(df_users)
        
print "Creating data frame from loaded data"
df_records = pd.DataFrame(user_records, columns=["uid", "name", "screen_name", "description", "verified", "location", "lat", "lon", "country", "created_at", "followers_count", "friends_count", "statuses_count", "favourites_count", "listed_count"])
print "Merging data frame with the training set"
df_full = pd.merge(df_users, df_records, on="uid", how="left")
print "Finished building data frame"
# Out:
# [0] User 202388889 already loaded
# [1] User 1392518336 already loaded
# [2] User 361208576 already loaded
# [3] User 1535215357 already loaded
# [4] User 4396196375 already loaded
# [5] User 17938477 already loaded
# [6] User 720288026681716737 already loaded
# [7] User 174004739 already loaded
# [8] User 53783678 already loaded
# [9] User 257662370 already loaded
# [10] User 4795355113 already loaded
# [11] User 1633971270 already loaded
# [12] User 2803810119 already loaded
# [13] User 2244770588 already loaded
# [14] User 102071251 already loaded
# [15] User 3358825450 already loaded
# [16] User 555940842 already loaded
# [17] User 2469354073 already loaded
# [18] User 360464656 already loaded
# [19] User 77243076 already loaded
# [20] User 1731752761 already loaded
# [21] User 2330149164 already loaded
# [22] User 2830586398 already loaded
# [23] User 443273019 already loaded
# [24] User 2591381383 already loaded
# [25] User 1093716612 already loaded
# [26] User 36620392 already loaded
# [27] User 3437626995 already loaded
# [28] User 387962514 already loaded
# [29] User 2938363689 already loaded
# [30] User 20930398 already loaded
# [31] User 143697407 already loaded
# [32] User 2291500309 already loaded
# [33] User 352663209 already loaded
# [34] User 14616266 already loaded
# [35] User 2277153890 already loaded
# [36] User 455246957 already loaded
# [37] User 1400974436 already loaded
# [38] User 449119247 already loaded
# [39] User 330816423 already loaded
# [40] User 29204608 already loaded
# [41] User 2733660094 already loaded
# [42] User 4756963587 already loaded
# [43] User 22045364 already loaded
# [44] User 4136625193 already loaded
# [45] User 372046661 already loaded
# [46] User 849310634 already loaded
# [47] User 24036997 already loaded
# [48] User 1141088486 already loaded
# [49] User 3014684283 already loaded
# [50] User 3293949957 already loaded
# [51] User 727272715665690624 already loaded
# [52] User 2752545437 already loaded
# [53] User 14368656 already loaded
# [54] User 20405419 already loaded
# [55] User 2682726528 already loaded
# [56] User 717841856785088512 already loaded
# [57] User 2889092479 already loaded
# [58] User 3182191980 already loaded
# [59] User 2582869146 already loaded
# [60] User 3092469172 already loaded
# [61] User 2826839454 already loaded
# [62] User 2660374267 already loaded
# [63] User 261625073 already loaded
# [64] User 233499930 already loaded
# [65] User 2664749580 already loaded
# [66] User 106594321 already loaded
# [67] User 722573847430504448 already loaded
# [68] User 3742834517 already loaded
# [69] User 735391716887429120 already loaded
# [70] User 241331375 already loaded
# [71] User 442382315 already loaded
# [72] User 16536054 already loaded
# [73] User 81324827 already loaded
# [74] User 583117972 already loaded
# [75] User 15800855 already loaded
# [76] User 705726066 already loaded
# [77] User 68857077 already loaded
# [78] User 197516080 already loaded
# [79] User 8685682 already loaded
# [80] User 2976908908 already loaded
# [81] User 2701255986 already loaded
# [82] User 620018150 already loaded
# [83] User 271451861 already loaded
# [84] User 194773838 already loaded
# [85] User 2893677862 already loaded
# [86] User 2392573227 already loaded
# [87] User 1195278157 already loaded
# [88] User 830253571 already loaded
# [89] User 377029968 already loaded
# [90] User 122799299 already loaded
# [91] User 27317580 already loaded
# [92] User 12754762 already loaded
# [93] User 85973106 already loaded
# [94] User 2873086293 already loaded
# [95] User 15751454 already loaded
# [96] User 591690042 already loaded
# [97] User 4092854173 already loaded
# [98] User 270212875 already loaded
# [99] User 870857718 already loaded
# [100] User 1663794048 already loaded
# [101] User 862290265 already loaded
# [102] User 707400118807482369 already loaded
# [103] User 17389503 already loaded
# [104] User 40768083 already loaded
# [105] User 243053328 already loaded
# [106] User 89662003 already loaded
# [107] User 17369567 already loaded
# [108] User 738921600 already loaded
# [109] User 604476686 already loaded
# [110] User 302563842 already loaded
# [111] User 247944133 already loaded
# [112] User 3331968983 already loaded
# [113] User 252434425 already loaded
# [114] User 2810127544 already loaded
# [115] User 156333299 already loaded
# [116] User 181336337 already loaded
# [117] User 3097175972 already loaded
# [118] User 186397253 already loaded
# [119] User 2866782904 already loaded
# [120] User 719914275771428866 already loaded
# [121] User 4900376472 already loaded
# [122] User 2412966416 already loaded
# [123] User 174141832 already loaded
# [124] User 64619482 already loaded
# [125] User 394974502 already loaded
# [126] User 2198704020 already loaded
# [127] User 18155773 already loaded
# [128] User 756335606607720450 already loaded
# [129] User 732808088810618880 already loaded
# [130] User 22286451 already loaded
# [131] User 96235518 already loaded
# [132] User 3091562110 was added to queue (total count = 1)
# [133] User 3195714762 already loaded
# [134] User 4112063532 already loaded
# [135] User 125868025 already loaded
# [136] User 737109737054056448 already loaded
# [137] User 103153950 already loaded
# [138] User 742777527467380742 already loaded
# [139] User 2976487163 already loaded
# [140] User 3123204560 already loaded
# [141] User 307445751 already loaded
# [142] User 250492272 already loaded
# [143] User 237443755 already loaded
# [144] User 33655372 already loaded
# [145] User 385759660 already loaded
# [146] User 2869813893 already loaded
# [147] User 37374348 already loaded
# [148] User 996399246 already loaded
# [149] User 15801372 already loaded
# [150] User 744682635188928512 already loaded
# [151] User 3091636366 already loaded
# [152] User 321213484 already loaded
# [153] User 940237466 already loaded
# [154] User 37214134 already loaded
# [155] User 2585090000 already loaded
# [156] User 861746341 already loaded
# [157] User 3145741085 already loaded
# [158] User 868252610 already loaded
# [159] User 19780786 already loaded
# [160] User 3556805776 already loaded
# [161] User 710823996032290816 already loaded
# [162] User 1534375489 already loaded
# [163] User 262939560 already loaded
# [164] User 360323271 already loaded
# [165] User 2204642713 already loaded
# [166] User 1574318594 already loaded
# [167] User 4384693707 already loaded
# [168] User 702559655461957632 already loaded
# [169] User 266867158 already loaded
# [170] User 484595690 already loaded
# [171] User 768806279309512705 already loaded
# [172] User 162500440 already loaded
# [173] User 3073503603 already loaded
# [174] User 1575902725 already loaded
# [175] User 1199251308 already loaded
# [176] User 48525928 already loaded
# [177] User 215698464 already loaded
# [178] User 2359225182 already loaded
# [179] User 13854472 already loaded
# [180] User 4853512997 already loaded
# [181] User 4505360352 already loaded
# [182] User 706466308976734208 already loaded
# [183] User 889022935 already loaded
# [184] User 2804090827 already loaded
# [185] User 2218957290 already loaded
# [186] User 305141481 already loaded
# [187] User 2807496454 already loaded
# [188] User 566871266 already loaded
# [189] User 396787338 already loaded
# [190] User 751804249084948480 already loaded
# [191] User 1633951202 already loaded
# [192] User 3059822856 already loaded
# [193] User 324191116 already loaded
# [194] User 2366569213 already loaded
# [195] User 3237611533 already loaded
# [196] User 93033299 already loaded
# [197] User 2834652729 already loaded
# [198] User 2679693610 already loaded
# [199] User 33443030 already loaded
# [200] User 609212773 already loaded
# [201] User 139881843 already loaded
# [202] User 13050712 already loaded
# [203] User 1593911304 already loaded
# [204] User 3105274249 already loaded
# [205] User 3099191 already loaded
# [206] User 766192139294367744 already loaded
# [207] User 1194986731 already loaded
# [208] User 4334014937 already loaded
# [209] User 581109471 already loaded
# [210] User 1624347776 already loaded
# [211] User 5673082 already loaded
# [212] User 1361623950 already loaded
# [213] User 1319277674 already loaded
# [214] User 1511217822 already loaded
# [215] User 2489712225 already loaded
# [216] User 156751345 already loaded
# [217] User 714717134 already loaded
# [218] User 23581650 already loaded
# [219] User 4909093579 already loaded
# [220] User 2440870033 already loaded
# [221] User 70276986 already loaded
# [222] User 22643886 already loaded
# [223] User 376449628 already loaded
# [224] User 746503986501541888 already loaded
# [225] User 1619363983 already loaded
# [226] User 2328392220 already loaded
# [227] User 366081170 already loaded
# [228] User 32943298 already loaded
# [229] User 755161479326859264 already loaded
# [230] User 30789320 already loaded
# [231] User 761640324267552768 already loaded
# [232] User 749905226 already loaded
# [233] User 1049419069 already loaded
# [234] User 948150751 already loaded
# [235] User 1556914716 already loaded
# [236] User 120661388 already loaded
# [237] User 805488692 already loaded
# [238] User 2399010342 already loaded
# [239] User 2847958116 already loaded
# [240] User 84909370 already loaded
# [241] User 392579325 already loaded
# [242] User 1491224984 already loaded
# [243] User 454189198 already loaded
# [244] User 859643052 already loaded
# [245] User 3004713411 already loaded
# [246] User 3231382825 already loaded
# [247] User 317074915 already loaded
# [248] User 377578563 already loaded
# [249] User 357674179 already loaded
# [250] User 757849337955180544 already loaded
# [251] User 32499271 already loaded
# [252] User 2881137610 already loaded
# [253] User 14146356 already loaded
# [254] User 23563560 already loaded
# [255] User 3466002195 already loaded
# [256] User 1715803561 already loaded
# [257] User 741228795466768384 already loaded
# [258] User 17589158 already loaded
# [259] User 863004894 already loaded
# [260] User 196728663 already loaded
# [261] User 28027426 already loaded
# [262] User 392904239 already loaded
# [263] User 145739275 already loaded
# [264] User 600761826 already loaded
# [265] User 298982890 already loaded
# [266] User 3255049069 already loaded
# [267] User 436740696 already loaded
# [268] User 752347799623196674 already loaded
# [269] User 2593236660 already loaded
# [270] User 4882314680 already loaded
# [271] User 253363609 already loaded
# [272] User 16280507 already loaded
# [273] User 1339229832 already loaded
# [274] User 2179534140 already loaded
# [275] User 724950499536019456 already loaded
# [276] User 710613745374920705 already loaded
# [277] User 2516724463 already loaded
# [278] User 19078594 already loaded
# [279] User 286626183 already loaded
# [280] User 274768374 already loaded
# [281] User 521810110 already loaded
# [282] User 564775361 already loaded
# [283] User 44481763 already loaded
# [284] User 301607114 already loaded
# [285] User 760201676187918336 was added to queue (total count = 2)
# [286] User 16675438 already loaded
# [287] User 701264676 already loaded
# [288] User 1313934584 already loaded
# [289] User 2326301849 already loaded
# [290] User 30714301 already loaded
# [291] User 769649548604084227 already loaded
# [292] User 251011762 already loaded
# [293] User 725850449765535745 already loaded
# [294] User 750460140604665856 already loaded
# [295] User 4860375540 already loaded
# [296] User 717875016667258880 already loaded
# [297] User 6755322 already loaded
# [298] User 42597573 already loaded
# [299] User 528984189 already loaded
# [300] User 4824442102 already loaded
# [301] User 4032966483 already loaded
# [302] User 2702449304 already loaded
# [303] User 240655988 already loaded
# [304] User 1681182696 already loaded
# [305] User 254712855 already loaded
# [306] User 235005003 already loaded
# [307] User 408519846 already loaded
# [308] User 506460264 already loaded
# [309] User 17068636 already loaded
# [310] User 28372736 already loaded
# [311] User 6335572 already loaded
# [312] User 33387382 already loaded
# [313] User 523907371 already loaded
# [314] User 707221196992020480 already loaded
# [315] User 45506413 already loaded
# [316] User 86656757 already loaded
# [317] User 312282367 already loaded
# [318] User 2461141921 already loaded
# [319] User 762872863 already loaded
# [320] User 541334839 already loaded
# [321] User 214356248 already loaded
# [322] User 363309009 already loaded
# [323] User 752621591209488385 already loaded
# [324] User 939543931 already loaded
# [325] User 15459746 already loaded
# [326] User 1318931731 already loaded
# [327] User 3065516115 already loaded
# [328] User 20179598 already loaded
# [329] User 2557992329 already loaded
# [330] User 750798507187941376 already loaded
# [331] User 1801037154 already loaded
# [332] User 517509150 already loaded
# [333] User 128099263 already loaded
# [334] User 228686398 already loaded
# [335] User 4100826221 already loaded
# [336] User 117560722 already loaded
# [337] User 1908456235 already loaded
# [338] User 3368114369 already loaded
# [339] User 743232499069886464 already loaded
# [340] User 482334246 already loaded
# [341] User 552316727 already loaded
# [342] User 4719090552 already loaded
# [343] User 911518862 already loaded
# [344] User 2989686880 already loaded
# [345] User 706954713 already loaded
# [346] User 19264069 already loaded
# [347] User 16624549 already loaded
# [348] User 981565406 already loaded
# [349] User 45295692 already loaded
# [350] User 757070187275231232 already loaded
# [351] User 169604722 already loaded
# [352] User 261306858 already loaded
# [353] User 769149124360937472 already loaded
# [354] User 2928711967 already loaded
# [355] User 3374673945 already loaded
# [356] User 18423141 already loaded
# [357] User 2409729842 already loaded
# [358] User 717136610517655552 already loaded
# [359] User 2837893122 already loaded
# [360] User 54653082 already loaded
# [361] User 2973997244 already loaded
# [362] User 16276186 already loaded
# [363] User 205396981 already loaded
# [364] User 3311663485 already loaded
# [365] User 741027626211549184 already loaded
# [366] User 2883128790 already loaded
# [367] User 55787027 already loaded
# [368] User 17689843 already loaded
# [369] User 1021139648 already loaded
# [370] User 2605287897 already loaded
# [371] User 256363443 already loaded
# [372] User 2356962151 already loaded
# [373] User 179665810 already loaded
# [374] User 107236390 already loaded
# [375] User 2831337577 already loaded
# [376] User 840430194 already loaded
# [377] User 446413281 already loaded
# [378] User 19739420 already loaded
# [379] User 729080067817615360 already loaded
# [380] User 485272452 already loaded
# [381] User 2782626491 already loaded
# [382] User 241395137 already loaded
# [383] User 112520214 already loaded
# [384] User 32947456 already loaded
# [385] User 2735876188 already loaded
# [386] User 2597132532 already loaded
# [387] User 43438089 already loaded
# [388] User 67031019 already loaded
# [389] User 459379674 already loaded
# [390] User 723516845425184769 already loaded
# [391] User 734632509326151682 already loaded
# [392] User 345062584 already loaded
# [393] User 26179029 already loaded
# [394] User 726635229226524672 already loaded
# [395] User 471747935 already loaded
# [396] User 764429523769106432 already loaded
# [397] User 371337165 already loaded
# [398] User 746633618345201664 already loaded
# [399] User 3415253711 already loaded
# [400] User 1646692903 already loaded
# [401] User 870510614 already loaded
# [402] User 95235772 already loaded
# [403] User 596117217 already loaded
# [404] User 548249031 already loaded
# [405] User 124730134 already loaded
# [406] User 32043963 already loaded
# [407] User 484476168 already loaded
# [408] User 966386515 already loaded
# [409] User 715960297593376768 already loaded
# [410] User 730900240149045248 already loaded
# [411] User 62305817 already loaded
# [412] User 2962194475 already loaded
# [413] User 1467783212 already loaded
# [414] User 4249177700 already loaded
# [415] User 3198016616 already loaded
# [416] User 2236299002 already loaded
# [417] User 1642106527 already loaded
# [418] User 129752995 already loaded
# [419] User 1353877376 already loaded
# [420] User 16063972 already loaded
# [421] User 2380025412 already loaded
# [422] User 2350402320 already loaded
# [423] User 65363823 already loaded
# [424] User 3688304901 already loaded
# [425] User 422279039 already loaded
# [426] User 966020486 already loaded
# [427] User 965512627 already loaded
# [428] User 1254436736 already loaded
# [429] User 3000736965 already loaded
# [430] User 741006180093440001 already loaded
# [431] User 385204671 already loaded
# [432] User 633271091 already loaded
# [433] User 769588045859459073 already loaded
# [434] User 14747394 already loaded
# [435] User 730570399939973120 already loaded
# [436] User 392969317 already loaded
# [437] User 2353822818 already loaded
# [438] User 863949348 already loaded
# [439] User 22378806 already loaded
# [440] User 3730977862 already loaded
# [441] User 17276219 already loaded
# [442] User 15630920 already loaded
# [443] User 2578875530 already loaded
# [444] User 67484867 already loaded
# [445] User 15142804 already loaded
# [446] User 764455186601504769 already loaded
# [447] User 4712071932 already loaded
# [448] User 904072386 already loaded
# [449] User 147852554 already loaded
# [450] User 1363651039 already loaded
# [451] User 16282693 already loaded
# [452] User 138093239 already loaded
# [453] User 119119142 already loaded
# [454] User 329897342 already loaded
# [455] User 738238064779272192 already loaded
# [456] User 52203579 already loaded
# [457] User 42426688 already loaded
# [458] User 1557723937 already loaded
# [459] User 1582255662 already loaded
# [460] User 973704955 already loaded
# [461] User 121606839 already loaded
# [462] User 20280591 already loaded
# [463] User 735409626297012224 already loaded
# [464] User 29837593 already loaded
# [465] User 1622658864 was added to queue (total count = 3)
# [466] User 1367666652 already loaded
# [467] User 3258538129 already loaded
# [468] User 203751233 already loaded
# [469] User 37232932 already loaded
# [470] User 173772400 already loaded
# [471] User 515326848 already loaded
# [472] User 40434781 already loaded
# [473] User 3310269630 already loaded
# [474] User 2726537421 already loaded
# [475] User 1215350906 already loaded
# [476] User 28174444 already loaded
# [477] User 429724961 already loaded
# [478] User 554264674 already loaded
# [479] User 80308520 already loaded
# [480] User 491666244 already loaded
# [481] User 110874872 already loaded
# [482] User 2373650969 already loaded
# [483] User 35724162 already loaded
# [484] User 64605066 already loaded
# [485] User 146811701 already loaded
# [486] User 2560409550 already loaded
# [487] User 2309170130 already loaded
# [488] User 219923514 already loaded
# [489] User 2544478364 already loaded
# [490] User 3188185608 already loaded
# [491] User 755695 already loaded
# [492] User 4696469899 already loaded
# [493] User 262907164 already loaded
# [494] User 15120921 already loaded
# [495] User 21702220 already loaded
# [496] User 4220390892 already loaded
# [497] User 3038432977 already loaded
# [498] User 398612282 already loaded
# [499] User 768806253841649665 already loaded
# [500] User 379140979 already loaded
# [501] User 46182858 already loaded
# [502] User 3127796386 already loaded
# [503] User 21048305 already loaded
# [504] User 44539994 already loaded
# [505] User 3740882714 already loaded
# [506] User 2827107229 already loaded
# [507] User 969130340 was added to queue (total count = 4)
# [508] User 758358493115977728 already loaded
# [509] User 162380937 already loaded
# [510] User 762749813817430016 already loaded
# [511] User 330388763 already loaded
# [512] User 868728822 already loaded
# [513] User 770394748083470336 already loaded
# [514] User 1319506603 already loaded
# [515] User 410491220 already loaded
# [516] User 721422997177937921 already loaded
# [517] User 20709244 already loaded
# [518] User 30678167 already loaded
# [519] User 539304644 already loaded
# [520] User 1341030121 already loaded
# [521] User 51469091 already loaded
# [522] User 222149255 already loaded
# [523] User 237568693 already loaded
# [524] User 2970995698 already loaded
# [525] User 163484443 already loaded
# [526] User 1379328662 already loaded
# [527] User 756514146 already loaded
# [528] User 97797669 already loaded
# [529] User 1607169578 already loaded
# [530] User 2688502513 already loaded
# [531] User 410191417 already loaded
# [532] User 15255690 already loaded
# [533] User 2839408042 already loaded
# [534] User 19300765 already loaded
# [535] User 1153713116 already loaded
# [536] User 2815895750 already loaded
# [537] User 35054585 already loaded
# [538] User 752690806843121664 already loaded
# [539] User 3297910826 already loaded
# [540] User 3116123438 already loaded
# [541] User 149894382 already loaded
# [542] User 200345016 already loaded
# [543] User 367683979 already loaded
# [544] User 323223493 already loaded
# [545] User 731855169034407936 already loaded
# [546] User 2837524258 already loaded
# [547] User 725067109 already loaded
# [548] User 2310897126 already loaded
# [549] User 164681009 already loaded
# [550] User 17726655 already loaded
# [551] User 1429145508 already loaded
# [552] User 1213690003 already loaded
# [553] User 474626406 already loaded
# [554] User 3318751062 already loaded
# [555] User 1739551255 already loaded
# [556] User 2834011466 already loaded
# [557] User 353826298 already loaded
# [558] User 2385538754 already loaded
# [559] User 734741758190493696 already loaded
# [560] User 21258949 already loaded
# [561] User 2388016309 already loaded
# [562] User 277091016 already loaded
# [563] User 1027382700 already loaded
# [564] User 3131613843 already loaded
# [565] User 1884780398 already loaded
# [566] User 2393506290 already loaded
# [567] User 2900026083 already loaded
# [568] User 1209867661 already loaded
# [569] User 4661070327 already loaded
# [570] User 1652036461 already loaded
# [571] User 730393178512175105 already loaded
# [572] User 3469521620 already loaded
# [573] User 69397756 already loaded
# [574] User 98773158 already loaded
# [575] User 344218796 already loaded
# [576] User 196458217 already loaded
# [577] User 268979226 already loaded
# [578] User 187403903 already loaded
# [579] User 215396680 already loaded
# [580] User 2650372441 already loaded
# [581] User 29678970 already loaded
# [582] User 274637876 already loaded
# [583] User 2253288175 already loaded
# [584] User 155351209 already loaded
# [585] User 725029122691489792 already loaded
# [586] User 533673215 already loaded
# [587] User 224546075 already loaded
# [588] User 189953011 already loaded
# [589] User 1966489658 already loaded
# [590] User 114698638 already loaded
# [591] User 2636241323 already loaded
# [592] User 17856110 already loaded
# [593] User 219546296 already loaded
# [594] User 199545574 already loaded
# [595] User 327214542 already loaded
# [596] User 1401698137 already loaded
# [597] User 354172611 already loaded
# [598] User 2466976567 already loaded
# [599] User 129044855 already loaded
# [600] User 256435851 already loaded
# [601] User 3044644978 already loaded
# [602] User 3255039836 already loaded
# [603] User 108892786 already loaded
# [604] User 3594672854 already loaded
# [605] User 345446299 already loaded
# [606] User 2575007515 already loaded
# [607] User 712177938259640320 already loaded
# [608] User 3148362085 already loaded
# [609] User 50875746 already loaded
# [610] User 3333983548 already loaded
# [611] User 3154569729 already loaded
# [612] User 3295740715 already loaded
# [613] User 20751648 already loaded
# [614] User 374490467 already loaded
# [615] User 1618976089 already loaded
# [616] User 81828940 already loaded
# [617] User 31098828 already loaded
# [618] User 813512664 already loaded
# [619] User 445558311 already loaded
# [620] User 49066447 already loaded
# [621] User 1872281394 already loaded
# [622] User 208655997 already loaded
# [623] User 2430958988 already loaded
# [624] User 32968728 already loaded
# [625] User 44845304 already loaded
# [626] User 1683935702 already loaded
# [627] User 2733864000 already loaded
# [628] User 2985614399 already loaded
# [629] User 1311631482 already loaded
# [630] User 299847363 already loaded
# [631] User 320000449 already loaded
# [632] User 369325711 already loaded
# [633] User 3391379543 already loaded
# [634] User 1544353886 already loaded
# [635] User 404609343 already loaded
# [636] User 712791788 already loaded
# [637] User 237796056 already loaded
# [638] User 507058341 already loaded
# [639] User 316874546 already loaded
# [640] User 143337751 already loaded
# [641] User 577614195 already loaded
# [642] User 4512682882 already loaded
# [643] User 741069969920819201 already loaded
# [644] User 346732820 already loaded
# [645] User 599256947 already loaded
# [646] User 557438271 already loaded
# [647] User 565156962 already loaded
# [648] User 3215730856 already loaded
# [649] User 773433722 already loaded
# [650] User 736167842039504897 already loaded
# [651] User 2555976170 already loaded
# [652] User 21091694 already loaded
# [653] User 221980247 already loaded
# [654] User 4302200483 already loaded
# [655] User 1248346406 already loaded
# [656] User 752262167437516800 already loaded
# [657] User 556259428 already loaded
# [658] User 20568320 already loaded
# [659] User 3088549203 already loaded
# [660] User 28809114 already loaded
# [661] User 2782504471 already loaded
# [662] User 2369435731 already loaded
# [663] User 261320586 already loaded
# [664] User 18590086 already loaded
# [665] User 186156580 already loaded
# [666] User 3313668872 already loaded
# [667] User 172988427 already loaded
# [668] User 42977470 already loaded
# [669] User 891698605 already loaded
# [670] User 868975614 already loaded
# [671] User 15246892 already loaded
# [672] User 4572842363 already loaded
# [673] User 1576888868 already loaded
# [674] User 2600907050 already loaded
# [675] User 734212266044837888 already loaded
# [676] User 1577945034 already loaded
# [677] User 710303563 already loaded
# [678] User 31320743 already loaded
# [679] User 3363578751 already loaded
# [680] User 295239689 already loaded
# [681] User 2386368001 already loaded
# [682] User 196653037 already loaded
# [683] User 534589970 already loaded
# [684] User 3195562057 already loaded
# [685] User 3376730953 already loaded
# [686] User 1591390472 already loaded
# [687] User 3475336995 already loaded
# [688] User 2915691653 already loaded
# [689] User 29596691 already loaded
# [690] User 446037325 already loaded
# [691] User 1341330798 already loaded
# [692] User 204997488 already loaded
# [693] User 4847157879 already loaded
# [694] User 66382897 already loaded
# [695] User 237982739 already loaded
# [696] User 6264612 already loaded
# [697] User 996500510 already loaded
# [698] User 209482433 already loaded
# [699] User 3420417017 already loaded
# [700] User 131362504 already loaded
# [701] User 80093264 already loaded
# [702] User 731651087871016960 already loaded
# [703] User 24238398 already loaded
# [704] User 2387746308 already loaded
# [705] User 101854095 already loaded
# [706] User 3023753980 already loaded
# [707] User 27403610 already loaded
# [708] User 245612661 already loaded
# [709] User 1595742206 already loaded
# [710] User 446730156 already loaded
# [711] User 3093390575 already loaded
# [712] User 2660251364 already loaded
# [713] User 2284029337 already loaded
# [714] User 729620388712349696 already loaded
# [715] User 354618612 already loaded
# [716] User 980462184 already loaded
# [717] User 3091812411 already loaded
# [718] User 368371386 already loaded
# [719] User 451954723 already loaded
# [720] User 419963584 already loaded
# [721] User 20726618 already loaded
# [722] User 83854160 already loaded
# [723] User 70061423 already loaded
# [724] User 2615587046 already loaded
# [725] User 74609386 already loaded
# [726] User 2211835920 already loaded
# [727] User 3685431973 already loaded
# [728] User 624555559 already loaded
# [729] User 126977959 already loaded
# [730] User 3284608501 already loaded
# [731] User 149129016 already loaded
# [732] User 703808295274811393 already loaded
# [733] User 763375106 already loaded
# [734] User 228203145 already loaded
# [735] User 120670045 already loaded
# [736] User 302930360 already loaded
# [737] User 748088250 already loaded
# [738] User 56154742 already loaded
# [739] User 4370281153 already loaded
# [740] User 14114579 already loaded
# [741] User 95776897 already loaded
# [742] User 2335643443 already loaded
# [743] User 1173505441 already loaded
# [744] User 29094472 already loaded
# [745] User 1969261 already loaded
# [746] User 3138302455 already loaded
# [747] User 3234520340 already loaded
# [748] User 2499870654 already loaded
# [749] User 190694770 already loaded
# [750] User 2766554164 already loaded
# [751] User 3303999714 already loaded
# [752] User 159935292 already loaded
# [753] User 15091467 already loaded
# [754] User 130500843 already loaded
# [755] User 1063750279 already loaded
# [756] User 1698006488 already loaded
# [757] User 555549494 already loaded
# [758] User 2434493347 already loaded
# [759] User 3243984962 already loaded
# [760] User 39977492 already loaded
# [761] User 3473508502 already loaded
# [762] User 4101677685 already loaded
# [763] User 563717228 already loaded
# [764] User 762800656650342402 already loaded
# [765] User 504840724 already loaded
# [766] User 123936058 already loaded
# [767] User 762430039317065728 already loaded
# [768] User 4585196953 already loaded
# [769] User 1305323082 already loaded
# [770] User 463292749 already loaded
# [771] User 418389641 already loaded
# [772] User 30480217 already loaded
# [773] User 3294981856 already loaded
# [774] User 996198924 already loaded
# [775] User 763128384553496577 already loaded
# [776] User 42891240 already loaded
# [777] User 1977249710 already loaded
# [778] User 561635422 already loaded
# [779] User 1343287051 already loaded
# [780] User 768616694285754368 already loaded
# [781] User 724244928 already loaded
# [782] User 634057623 already loaded
# [783] User 2893030210 already loaded
# [784] User 706638506475577344 already loaded
# [785] User 114954534 already loaded
# [786] User 4921836612 already loaded
# [787] User 8376452 already loaded
# [788] User 3148955279 already loaded
# [789] User 3025857854 already loaded
# [790] User 269383362 already loaded
# [791] User 2450544780 already loaded
# [792] User 237971863 already loaded
# [793] User 14733264 already loaded
# [794] User 2202222554 already loaded
# [795] User 3606793272 already loaded
# [796] User 635442836 already loaded
# [797] User 280017388 already loaded
# [798] User 36711098 already loaded
# [799] User 3756221421 already loaded
# [800] User 114455332 already loaded
# [801] User 2208161496 already loaded
# [802] User 3757214232 already loaded
# [803] User 52904511 already loaded
# [804] User 1969712454 already loaded
# [805] User 113527566 already loaded
# [806] User 1663496635 already loaded
# [807] User 3305493985 already loaded
# [808] User 377063008 already loaded
# [809] User 2875636889 already loaded
# [810] User 259327767 already loaded
# [811] User 867144884 already loaded
# [812] User 751075910820986880 already loaded
# [813] User 768806658839420930 already loaded
# [814] User 863226571 already loaded
# [815] User 17939301 already loaded
# [816] User 125213776 already loaded
# [817] User 31096602 already loaded
# [818] User 753205316297363456 already loaded
# [819] User 433288765 already loaded
# [820] User 252300306 already loaded
# [821] User 630289964 already loaded
# [822] User 4852062464 already loaded
# [823] User 610891435 already loaded
# [824] User 2277557854 already loaded
# [825] User 2849182766 already loaded
# [826] User 60557242 already loaded
# [827] User 22924791 already loaded
# [828] User 1022739794 already loaded
# [829] User 3035045041 already loaded
# [830] User 29856059 already loaded
# [831] User 1161783374 already loaded
# [832] User 21671638 already loaded
# [833] User 578043427 already loaded
# [834] User 229291124 already loaded
# [835] User 203430800 already loaded
# [836] User 172461030 already loaded
# [837] User 710123098876420096 already loaded
# [838] User 764934252785963008 already loaded
# [839] User 3074165205 already loaded
# [840] User 43628439 already loaded
# [841] User 859065464 already loaded
# [842] User 16653588 already loaded
# [843] User 2335832054 already loaded
# [844] User 22851978 already loaded
# [845] User 44949602 already loaded
# [846] User 17596197 already loaded
# [847] User 89850730 already loaded
# [848] User 409219430 already loaded
# [849] User 85596203 already loaded
# [850] User 471616553 already loaded
# [851] User 203933442 already loaded
# [852] User 722869267192909826 already loaded
# [853] User 1340195240 already loaded
# [854] User 961897970 already loaded
# [855] User 1758169249 already loaded
# [856] User 210917229 already loaded
# [857] User 2544711450 already loaded
# [858] User 716489867551764480 already loaded
# [859] User 770716977048453121 already loaded
# [860] User 712835244047540224 already loaded
# [861] User 362454062 already loaded
# [862] User 170761737 already loaded
# [863] User 1364623915 already loaded
# [864] User 2581598156 already loaded
# [865] User 716934863316656128 already loaded
# [866] User 359738503 already loaded
# [867] User 1948293908 already loaded
# [868] User 29322673 already loaded
# [869] User 314015099 already loaded
# [870] User 269972688 already loaded
# [871] User 1093187196 already loaded
# [872] User 416790643 already loaded
# [873] User 971426569 already loaded
# [874] User 259310022 already loaded
# [875] User 1654399368 already loaded
# [876] User 7914392 already loaded
# [877] User 565902907 already loaded
# [878] User 716383412832092160 already loaded
# [879] User 2905649003 already loaded
# [880] User 370102470 already loaded
# [881] User 286842962 already loaded
# [882] User 95856276 already loaded
# [883] User 2266139084 already loaded
# [884] User 761341696621867008 already loaded
# [885] User 634949386 already loaded
# [886] User 1053390794 already loaded
# [887] User 4918960069 already loaded
# [888] User 17010273 already loaded
# [889] User 1638976808 already loaded
# [890] User 767093070378786818 already loaded
# [891] User 2385451059 already loaded
# [892] User 3677099718 already loaded
# [893] User 360211782 already loaded
# [894] User 64103824 already loaded
# [895] User 928791588 already loaded
# [896] User 714506718634336256 already loaded
# [897] User 715253629058416642 already loaded
# [898] User 22096537 already loaded
# [899] User 299480333 already loaded
# [900] User 533643767 already loaded
# [901] User 477975738 already loaded
# [902] User 2837736946 already loaded
# [903] User 163508092 already loaded
# [904] User 65974890 already loaded
# [905] User 442061362 already loaded
# [906] User 3131916621 already loaded
# [907] User 3096607562 already loaded
# [908] User 4873894875 already loaded
# [909] User 14810072 already loaded
# [910] User 6065452 already loaded
# [911] User 346476440 already loaded
# [912] User 54255836 already loaded
# [913] User 736205517987676160 already loaded
# [914] User 16059376 already loaded
# [915] User 100895378 already loaded
# [916] User 2218315310 already loaded
# [917] User 202905814 already loaded
# [918] User 268827675 already loaded
# [919] User 3918521178 already loaded
# [920] User 2277907310 already loaded
# [921] User 2463664681 already loaded
# [922] User 321687893 already loaded
# [923] User 110889275 already loaded
# [924] User 759953831866294272 already loaded
# [925] User 2396045375 already loaded
# [926] User 251304381 already loaded
# [927] User 222135382 already loaded
# [928] User 410350463 already loaded
# [929] User 83891821 already loaded
# [930] User 3034756466 already loaded
# [931] User 21352807 already loaded
# [932] User 1928317970 already loaded
# [933] User 102673526 already loaded
# [934] User 8961432 already loaded
# [935] User 703783237819240448 already loaded
# [936] User 1342622455 already loaded
# [937] User 3829391963 already loaded
# [938] User 339888066 already loaded
# [939] User 8410672 already loaded
# [940] User 726105437125365760 already loaded
# [941] User 3433749755 already loaded
# [942] User 2303320040 already loaded
# [943] User 86980188 already loaded
# [944] User 36600790 already loaded
# [945] User 3289098415 already loaded
# [946] User 3093859981 already loaded
# [947] User 4115628201 already loaded
# [948] User 80385238 already loaded
# [949] User 1591639044 already loaded
# [950] User 48564052 already loaded
# [951] User 107043993 already loaded
# [952] User 2883666819 already loaded
# [953] User 1679732623 already loaded
# [954] User 24757120 already loaded
# [955] User 172593752 already loaded
# [956] User 2875974692 already loaded
# [957] User 842074315 already loaded
# [958] User 7501832 already loaded
# [959] User 1919647429 already loaded
# [960] User 14832328 already loaded
# [961] User 30064493 already loaded
# [962] User 386847907 already loaded
# [963] User 80876513 already loaded
# [964] User 4690149541 already loaded
# [965] User 20327465 already loaded
# [966] User 33014050 already loaded
# [967] User 4443273859 already loaded
# [968] User 733710370569883648 already loaded
# [969] User 4788911909 already loaded
# [970] User 40851610 already loaded
# [971] User 1656931974 already loaded
# [972] User 3373120661 already loaded
# [973] User 702496942589345792 already loaded
# [974] User 2862956911 already loaded
# [975] User 2342689699 already loaded
# [976] User 46943898 already loaded
# [977] User 1462621352 already loaded
# [978] User 2502043052 already loaded
# [979] User 319334173 already loaded
# [980] User 2812221331 already loaded
# [981] User 197874698 already loaded
# [982] User 1477858615 already loaded
# [983] User 508866003 already loaded
# [984] User 59771181 already loaded
# [985] User 17294419 already loaded
# [986] User 22542200 already loaded
# [987] User 417441665 already loaded
# [988] User 861408704 already loaded
# [989] User 2871454226 already loaded
# [990] User 729801779722883072 already loaded
# [991] User 3247466372 already loaded
# [992] User 38899996 already loaded
# [993] User 3029949939 already loaded
# [994] User 331468642 already loaded
# [995] User 1464058206 already loaded
# [996] User 49581497 already loaded
# [997] User 141701133 already loaded
# [998] User 3180615749 was added to queue (total count = 5)
# [999] User 274126966 already loaded
# [1000] User 805028582 already loaded
# [1001] User 14124866 already loaded
# [1002] User 14836470 already loaded
# [1003] User 62176214 already loaded
# [1004] User 410076120 already loaded
# [1005] User 219856891 already loaded
# [1006] User 721758189054599168 already loaded
# [1007] User 467195236 already loaded
# [1008] User 3349867499 already loaded
# [1009] User 24256374 already loaded
# [1010] User 1031586097 already loaded
# [1011] User 701085787987685376 already loaded
# [1012] User 4805180533 already loaded
# [1013] User 14445139 already loaded
# [1014] User 1477389409 already loaded
# [1015] User 21253604 already loaded
# [1016] User 1278209767 already loaded
# [1017] User 4778619409 already loaded
# [1018] User 3376721375 already loaded
# [1019] User 2569867838 already loaded
# [1020] User 3325814262 already loaded
# [1021] User 2429668927 already loaded
# [1022] User 505760318 already loaded
# [1023] User 16191023 already loaded
# [1024] User 3366716715 already loaded
# [1025] User 55640170 already loaded
# [1026] User 2738388295 already loaded
# [1027] User 2459751696 already loaded
# [1028] User 3184574766 already loaded
# [1029] User 363562246 already loaded
# [1030] User 743534678901202945 already loaded
# [1031] User 2349282882 already loaded
# [1032] User 14340736 already loaded
# [1033] User 28528123 already loaded
# [1034] User 715173887953088512 already loaded
# [1035] User 18259007 already loaded
# [1036] User 1385658037 already loaded
# [1037] User 157951320 already loaded
# [1038] User 1430858473 already loaded
# [1039] User 53657668 already loaded
# [1040] User 518617763 already loaded
# [1041] User 1186025425 already loaded
# [1042] User 384276856 already loaded
# [1043] User 874730298 already loaded
# [1044] User 46764970 already loaded
# [1045] User 308904438 already loaded
# [1046] User 724702770096283648 already loaded
# [1047] User 606026741 already loaded
# [1048] User 277770740 already loaded
# [1049] User 531595476 already loaded
# [1050] User 1700745378 already loaded
# [1051] User 2766516970 already loaded
# [1052] User 2829674873 already loaded
# [1053] User 3080868576 already loaded
# [1054] User 4864218259 already loaded
# [1055] User 2838892526 already loaded
# [1056] User 2564142475 already loaded
# [1057] User 4378425017 already loaded
# [1058] User 2291708942 already loaded
# [1059] User 737870316614090752 was added to queue (total count = 6)
# [1060] User 143052179 already loaded
# [1061] User 15162892 already loaded
# [1062] User 752664735351468034 already loaded
# [1063] User 2896714066 already loaded
# [1064] User 14477074 already loaded
# [1065] User 19418794 already loaded
# [1066] User 2476976133 already loaded
# [1067] User 22249964 already loaded
# [1068] User 374594322 already loaded
# [1069] User 59954867 already loaded
# [1070] User 1573876094 already loaded
# [1071] User 1712831 already loaded
# [1072] User 4664788752 already loaded
# [1073] User 53932566 already loaded
# [1074] User 46958419 already loaded
# [1075] User 605031919 already loaded
# [1076] User 238828295 already loaded
# [1077] User 1925476452 already loaded
# [1078] User 3012573742 already loaded
# [1079] User 7350052 already loaded
# [1080] User 755240387174858752 already loaded
# [1081] User 85383187 already loaded
# [1082] User 3191720604 already loaded
# [1083] User 2864506134 already loaded
# [1084] User 3415059471 already loaded
# [1085] User 2224180624 already loaded
# [1086] User 3021980538 already loaded
# [1087] User 16854309 already loaded
# [1088] User 86725587 already loaded
# [1089] User 2493899774 already loaded
# [1090] User 231470127 already loaded
# [1091] User 751236619319947265 already loaded
# [1092] User 755375583979155456 already loaded
# [1093] User 22832708 already loaded
# [1094] User 3309991664 already loaded
# [1095] User 20945621 already loaded
# [1096] User 69477433 already loaded
# [1097] User 313625705 already loaded
# [1098] User 77648985 already loaded
# [1099] User 3139299528 already loaded
# [1100] User 3376671688 already loaded
# [1101] User 108360666 already loaded
# [1102] User 920000268 already loaded
# [1103] User 635011487 already loaded
# [1104] User 779314886 already loaded
# [1105] User 321652534 already loaded
# [1106] User 2934220776 already loaded
# [1107] User 2835630318 already loaded
# [1108] User 948380118 already loaded
# [1109] User 267936634 already loaded
# [1110] User 8518072 already loaded
# [1111] User 3196305816 already loaded
# [1112] User 1931226824 already loaded
# [1113] User 3150180776 already loaded
# [1114] User 2553124200 already loaded
# [1115] User 2856729550 already loaded
# [1116] User 2217809411 already loaded
# [1117] User 167429082 already loaded
# [1118] User 932703601 already loaded
# [1119] User 2870848881 already loaded
# [1120] User 409506562 already loaded
# [1121] User 2544594204 already loaded
# [1122] User 55610483 already loaded
# [1123] User 273535254 already loaded
# [1124] User 1713903728 already loaded
# [1125] User 3288930293 already loaded
# [1126] User 503353575 already loaded
# [1127] User 4512868294 already loaded
# [1128] User 16471256 already loaded
# [1129] User 712765109207175173 already loaded
# [1130] User 3192693609 already loaded
# [1131] User 267004350 already loaded
# [1132] User 711802172770557952 already loaded
# [1133] User 2154061080 already loaded
# [1134] User 3040779431 was added to queue (total count = 7)
# [1135] User 4829744572 already loaded
# [1136] User 1515041251 already loaded
# [1137] User 3388245413 already loaded
# [1138] User 82526109 already loaded
# [1139] User 557828551 already loaded
# [1140] User 734847737305300992 already loaded
# [1141] User 57998022 already loaded
# [1142] User 3238639359 already loaded
# [1143] User 364928508 already loaded
# [1144] User 3041300267 already loaded
# [1145] User 4705133474 already loaded
# [1146] User 4286971339 already loaded
# [1147] User 815639341 already loaded
# [1148] User 4779763407 already loaded
# [1149] User 432809372 already loaded
# [1150] User 2894555758 already loaded
# [1151] User 710828836196212737 already loaded
# [1152] User 354635776 already loaded
# [1153] User 18397062 already loaded
# [1154] User 2904244916 already loaded
# [1155] User 1689338184 already loaded
# [1156] User 3136367828 already loaded
# [1157] User 2847221676 already loaded
# [1158] User 499891595 already loaded
# [1159] User 2411113649 already loaded
# [1160] User 1944524948 already loaded
# [1161] User 371004542 already loaded
# [1162] User 2261047882 already loaded
# [1163] User 2193787283 already loaded
# [1164] User 954513102 already loaded
# [1165] User 139940291 already loaded
# [1166] User 2419866354 already loaded
# [1167] User 131374464 already loaded
# [1168] User 64588252 already loaded
# [1169] User 14744982 already loaded
# [1170] User 64216503 already loaded
# [1171] User 112324139 already loaded
# [1172] User 1894286120 already loaded
# [1173] User 4158942198 already loaded
# [1174] User 732046506698510336 already loaded
# [1175] User 147285071 already loaded
# [1176] User 374163386 already loaded
# [1177] User 83397587 already loaded
# [1178] User 148921176 already loaded
# [1179] User 4863483359 already loaded
# [1180] User 1463209370 already loaded
# [1181] User 588125997 already loaded
# [1182] User 17716516 already loaded
# [1183] User 160245128 already loaded
# [1184] User 247629502 already loaded
# [1185] User 294665606 already loaded
# [1186] User 306618321 already loaded
# [1187] User 583369707 already loaded
# [1188] User 4606105273 already loaded
# [1189] User 1244761950 already loaded
# [1190] User 62868886 already loaded
# [1191] User 3041943643 already loaded
# [1192] User 543456153 already loaded
# [1193] User 2327536579 already loaded
# [1194] User 2666442449 already loaded
# [1195] User 26167693 already loaded
# [1196] User 2561894326 already loaded
# [1197] User 3082278496 already loaded
# [1198] User 586035556 already loaded
# [1199] User 1668586344 already loaded
# [1200] User 45213380 already loaded
# [1201] User 4760755692 already loaded
# [1202] User 1073497698 already loaded
# [1203] User 748762612603637760 already loaded
# [1204] User 16998963 already loaded
# [1205] User 17395210 already loaded
# [1206] User 144629987 already loaded
# [1207] User 402697894 already loaded
# [1208] User 200821395 already loaded
# [1209] User 239480077 already loaded
# [1210] User 796515866 already loaded
# [1211] User 2995432916 already loaded
# [1212] User 9215822 already loaded
# [1213] User 16843235 already loaded
# [1214] User 418155088 already loaded
# [1215] User 299450805 already loaded
# [1216] User 571707970 already loaded
# [1217] User 711586995936612352 already loaded
# [1218] User 1978550202 already loaded
# [1219] User 2470203513 already loaded
# [1220] User 126749473 already loaded
# [1221] User 1975912297 already loaded
# [1222] User 59391711 already loaded
# [1223] User 101873187 already loaded
# [1224] User 17912843 already loaded
# [1225] User 726776829927895040 already loaded
# [1226] User 2275512848 already loaded
# [1227] User 162572003 already loaded
# [1228] User 139180102 already loaded
# [1229] User 74943067 already loaded
# [1230] User 365093718 already loaded
# [1231] User 24702493 already loaded
# [1232] User 157713354 already loaded
# [1233] User 748333335290601472 already loaded
# [1234] User 3096401610 already loaded
# [1235] User 767463599732318208 already loaded
# [1236] User 2811108358 already loaded
# [1237] User 3338910806 already loaded
# [1238] User 2859571540 already loaded
# [1239] User 752282119607431168 already loaded
# [1240] User 39955089 already loaded
# [1241] User 1576727964 already loaded
# [1242] User 1441404691 already loaded
# [1243] User 18044495 already loaded
# [1244] User 719069713297469440 already loaded
# [1245] User 2275310376 already loaded
# [1246] User 2654347764 already loaded
# [1247] User 537943650 already loaded
# [1248] User 2806141928 already loaded
# [1249] User 173499659 already loaded
# [1250] User 151442562 already loaded
# [1251] User 1701933138 already loaded
# [1252] User 15097133 already loaded
# [1253] User 749000792305172481 already loaded
# [1254] User 1565620440 already loaded
# [1255] User 14136582 already loaded
# [1256] User 2882920097 already loaded
# [1257] User 4009588632 already loaded
# [1258] User 2237233028 already loaded
# [1259] User 357491164 already loaded
# [1260] User 71041351 already loaded
# [1261] User 154142611 already loaded
# [1262] User 2910854367 already loaded
# [1263] User 768806372766916608 already loaded
# [1264] User 3795512897 already loaded
# [1265] User 81617002 already loaded
# [1266] User 737576178089758721 already loaded
# [1267] User 302497032 already loaded
# [1268] User 211140018 already loaded
# [1269] User 616722865 already loaded
# [1270] User 17238457 already loaded
# [1271] User 7372952 already loaded
# [1272] User 281196393 already loaded
# [1273] User 132033818 already loaded
# [1274] User 119122834 already loaded
# [1275] User 1725610087 already loaded
# [1276] User 1355683339 already loaded
# [1277] User 3002647860 already loaded
# [1278] User 218012342 already loaded
# [1279] User 336951477 already loaded
# [1280] User 107547335 already loaded
# [1281] User 768135762667864068 already loaded
# [1282] User 303006500 already loaded
# [1283] User 276629808 already loaded
# [1284] User 430924776 already loaded
# [1285] User 40090885 already loaded
# [1286] User 3173169669 already loaded
# ...
# [7312] User 2842384482 already loaded
# [7313] User 704380756072608000 was added to queue (total count = 62)
# [7314] User 16401090 already loaded
# [7315] User 1093428416 already loaded
# [7316] User 192700508 already loaded
# [7317] User 3228910307 already loaded
# [7318] User 702709923701002000 was added to queue (total count = 63)
# [7319] User 3303414113 already loaded
# [7320] User 2712696999 already loaded
# [7321] User 1970326891 already loaded
# [7322] User 762491273764668000 was added to queue (total count = 64)
# [7323] User 903585026 already loaded
# [7324] User 515530584 already loaded
# [7325] User 18542533 already loaded
# [7326] User 350063679 already loaded
# [7327] User 57721764 already loaded
# [7328] User 34095646 already loaded
# [7329] User 322449680 already loaded
# [7330] User 28007445 already loaded
# [7331] User 255797817 already loaded
# [7332] User 1180122894 already loaded
# [7333] User 462362715 already loaded
# [7334] User 713195014226969000 was added to queue (total count = 65)
# [7335] User 3341374872 already loaded
# [7336] User 3054535009 already loaded
# [7337] User 748972027587858000 was added to queue (total count = 66)
# [7338] User 354454666 already loaded
# [7339] User 21142500 already loaded
# [7340] User 1520839758 already loaded
# [7341] User 2603344777 already loaded
# [7342] User 2472407704 already loaded
# [7343] User 735190070102217000 was added to queue (total count = 67)
# [7344] User 253800985 already loaded
# [7345] User 26873441 already loaded
# [7346] User 3371982744 already loaded
# [7347] User 26593115 already loaded
# [7348] User 696374606458986000 was added to queue (total count = 68)
# [7349] User 4722814103 already loaded
# [7350] User 485662927 already loaded
# [7351] User 766603772713992000 was added to queue (total count = 69)
# [7352] User 3941315718 already loaded
# [7353] User 3219544890 already loaded
# [7354] User 345112065 already loaded
# [7355] User 199343831 already loaded
# [7356] User 420112221 already loaded
# [7357] User 711425714919084000 was added to queue (total count = 70)
# [7358] User 842648402 already loaded
# [7359] User 3307498525 already loaded
# [7360] User 4512705677 already loaded
# [7361] User 4574019075 already loaded
# [7362] User 389528617 already loaded
# [7363] User 1661279869 already loaded
# [7364] User 944282263 already loaded
# [7365] User 143207585 already loaded
# [7366] User 258758996 already loaded
# [7367] User 703204400353964000 was added to queue (total count = 71)
# [7368] User 325702047 already loaded
# [7369] User 287310360 already loaded
# [7370] User 4153516823 already loaded
# [7371] User 3391680893 already loaded
# [7372] User 243208668 already loaded
# [7373] User 709234809936204000 was added to queue (total count = 72)
# [7374] User 295727137 already loaded
# [7375] User 627093902 already loaded
# [7376] User 157584905 already loaded
# [7377] User 1021644103 already loaded
# [7378] User 3427922087 already loaded
# [7379] User 172498731 already loaded
# [7380] User 1220986278 already loaded
# [7381] User 2904005992 already loaded
# [7382] User 130964264 already loaded
# [7383] User 138236592 already loaded
# [7384] User 38424077 already loaded
# [7385] User 230103508 already loaded
# [7386] User 75974260 already loaded
# [7387] User 752134848492540000 was added to queue (total count = 73)
# [7388] User 160019620 already loaded
# [7389] User 546162406 already loaded
# [7390] User 3320708281 already loaded
# [7391] User 313420384 already loaded
# [7392] User 1123215325 already loaded
# [7393] User 2191188842 already loaded
# [7394] User 449123337 already loaded
# [7395] User 3407347630 already loaded
# [7396] User 45483298 already loaded
# [7397] User 257345787 already loaded
# [7398] User 19578308 already loaded
# [7399] User 61048036 already loaded
# [7400] User 190117171 already loaded
# [7401] User 745436057089413000 was added to queue (total count = 74)
# [7402] User 103462191 already loaded
# [7403] User 17023049 already loaded
# [7404] User 2199362023 already loaded
# [7405] User 33892144 already loaded
# [7406] User 266249753 already loaded
# [7407] User 765103727808086000 was added to queue (total count = 75)
# [7408] User 2870699914 already loaded
# [7409] User 521946169 already loaded
# [7410] User 250820008 already loaded
# [7411] User 755089743797428000 was added to queue (total count = 76)
# [7412] User 3078256288 already loaded
# [7413] User 22328001 already loaded
# [7414] User 372065527 already loaded
# [7415] User 233066204 already loaded
# [7416] User 4823193333 already loaded
# [7417] User 53722345 already loaded
# [7418] User 1338069978 already loaded
# [7419] User 23247050 already loaded
# [7420] User 613629503 already loaded
# [7421] User 752910397490000000 was added to queue (total count = 77)
# [7422] User 54725646 already loaded
# [7423] User 3235358144 already loaded
# [7424] User 35854184 already loaded
# [7425] User 758217917485847000 was added to queue (total count = 78)
# [7426] User 2796068560 already loaded
# [7427] User 769032841 already loaded
# [7428] User 966632690 already loaded
# [7429] User 1017888036 already loaded
# [7430] User 366512018 already loaded
# [7431] User 20298292 already loaded
# [7432] User 110610806 already loaded
# [7433] User 3331264479 already loaded
# [7434] User 3001588234 already loaded
# [7435] User 170946345 already loaded
# [7436] User 2570219694 already loaded
# [7437] User 196553866 already loaded
# [7438] User 3320149361 already loaded
# [7439] User 288356254 already loaded
# [7440] User 2587979840 already loaded
# [7441] User 525167971 already loaded
# [7442] User 2179032222 already loaded
# [7443] User 1891241 already loaded
# [7444] User 15102468 already loaded
# [7445] User 2449767427 already loaded
# [7446] User 2523322556 already loaded
# [7447] User 66337549 already loaded
# [7448] User 1971160087 already loaded
# [7449] User 3091493685 already loaded
# [7450] User 125467653 already loaded
# [7451] User 1043247924 already loaded
# [7452] User 28117898 already loaded
# [7453] User 2976014469 already loaded
# [7454] User 127384120 already loaded
# [7455] User 632957416 already loaded
# [7456] User 42513476 already loaded
# [7457] User 84521826 already loaded
# [7458] User 759926406 already loaded
# [7459] User 3252662579 already loaded
# [7460] User 1281452935 already loaded
# [7461] User 3344038420 already loaded
# [7462] User 440463725 already loaded
# [7463] User 753779827942035000 was added to queue (total count = 79)
# [7464] User 18065266 already loaded
# [7465] User 3156863358 already loaded
# [7466] User 383529009 already loaded
# [7467] User 612134519 already loaded
# [7468] User 731079272 already loaded
# [7469] User 22642511 already loaded
# [7470] User 515206505 already loaded
# [7471] User 2803909592 already loaded
# [7472] User 141031132 already loaded
# [7473] User 245760152 already loaded
# [7474] User 2470894041 already loaded
# [7475] User 250673246 already loaded
# [7476] User 3387601721 already loaded
# [7477] User 486409895 already loaded
# [7478] User 2657198670 already loaded
# [7479] User 2996226615 already loaded
# [7480] User 40941170 already loaded
# [7481] User 27335664 already loaded
# [7482] User 49197924 already loaded
# [7483] User 4254943407 already loaded
# [7484] User 712416526767252000 was added to queue (total count = 80)
# [7485] User 186876807 already loaded
# [7486] User 725831300314239000 was added to queue (total count = 81)
# [7487] User 38639934 already loaded
# [7488] User 308599937 already loaded
# [7489] User 768729239310840000 was added to queue (total count = 82)
# [7490] User 567959445 already loaded
# [7491] User 64886909 already loaded
# [7492] User 3983541023 already loaded
# [7493] User 2272028385 already loaded
# [7494] User 1603979245 already loaded
# [7495] User 47399828 already loaded
# [7496] User 548854675 already loaded
# [7497] User 178102985 already loaded
# [7498] User 50435693 already loaded
# [7499] User 1901339503 already loaded
# [7500] User 314870537 already loaded
# [7501] User 737540054 already loaded
# [7502] User 2174474448 already loaded
# [7503] User 855360499 already loaded
# [7504] User 65781271 already loaded
# [7505] User 416456405 already loaded
# [7506] User 1622231011 was added to queue (total count = 83)
# [7507] User 933638226 already loaded
# [7508] User 391016685 already loaded
# [7509] User 3347222434 already loaded
# [7510] User 1126978538 already loaded
# [7511] User 3235573818 already loaded
# [7512] User 2436871010 already loaded
# [7513] User 253227191 already loaded
# [7514] User 184646457 already loaded
# [7515] User 2213294077 already loaded
# [7516] User 1347676214 already loaded
# [7517] User 136128142 already loaded
# [7518] User 43595358 already loaded
# [7519] User 1379908728 already loaded
# [7520] User 2331070124 already loaded
# [7521] User 1324698565 already loaded
# [7522] User 4758279742 already loaded
# [7523] User 1567242546 already loaded
# [7524] User 113480677 already loaded
# [7525] User 47801335 already loaded
# [7526] User 705146754459537000 was added to queue (total count = 84)
# [7527] User 90370101 already loaded
# [7528] User 3135171759 already loaded
# [7529] User 4607024296 already loaded
# [7530] User 388515711 already loaded
# [7531] User 23712366 already loaded
# [7532] User 3233717170 already loaded
# [7533] User 2413824427 already loaded
# [7534] User 3139074203 already loaded
# [7535] User 711607776 already loaded
# [7536] User 91042892 already loaded
# [7537] User 251156150 already loaded
# [7538] User 2344311116 already loaded
# [7539] User 242929882 already loaded
# [7540] User 3836650812 already loaded
# [7541] User 163690896 already loaded
# [7542] User 240346682 already loaded
# [7543] User 290147834 already loaded
# [7544] User 747733206275867000 was added to queue (total count = 85)
# [7545] User 115509358 already loaded
# [7546] User 161470437 already loaded
# [7547] User 143119199 already loaded
# [7548] User 2578224075 already loaded
# [7549] User 451875319 already loaded
# [7550] User 242961973 already loaded
# [7551] User 79231745 already loaded
# [7552] User 464245638 already loaded
# [7553] User 3070799310 already loaded
# [7554] User 743481497475293000 was added to queue (total count = 86)
# [7555] User 4013818875 already loaded
# [7556] User 38404728 already loaded
# [7557] User 18847443 already loaded
# [7558] User 726613116117619000 was added to queue (total count = 87)
# [7559] User 13529572 already loaded
# [7560] User 246686930 already loaded
# [7561] User 2555589696 already loaded
# [7562] User 2387366754 already loaded
# [7563] User 85442820 already loaded
# [7564] User 265811201 already loaded
# [7565] User 722539478 already loaded
# [7566] User 224231200 already loaded
# [7567] User 729453477609525000 was added to queue (total count = 88)
# [7568] User 2835624240 already loaded
# [7569] User 220880605 already loaded
# [7570] User 437058481 already loaded
# [7571] User 14344474 already loaded
# [7572] User 428621116 already loaded
# [7573] User 1928746560 already loaded
# [7574] User 3711072372 already loaded
# [7575] User 2222233488 already loaded
# [7576] User 4877138025 already loaded
# [7577] User 3302943871 already loaded
# [7578] User 72598945 already loaded
# [7579] User 2414984580 already loaded
# [7580] User 825775182 already loaded
# [7581] User 3924951315 already loaded
# [7582] User 2984412522 already loaded
# [7583] User 15595930 already loaded
# [7584] User 15978636 already loaded
# [7585] User 98358734 already loaded
# [7586] User 195226150 already loaded
# [7587] User 4136050276 already loaded
# [7588] User 714111713315041000 was added to queue (total count = 89)
# [7589] User 715738086097850000 was added to queue (total count = 90)
# [7590] User 2865969087 already loaded
# [7591] User 831474091 already loaded
# [7592] User 557991042 already loaded
# [7593] User 1850382810 already loaded
# [7594] User 65727414 already loaded
# [7595] User 2288874470 already loaded
# [7596] User 23078306 already loaded
# [7597] User 318297521 already loaded
# [7598] User 3290576961 already loaded
# [7599] User 3975129617 already loaded
# [7600] User 969990860 already loaded
# [7601] User 49850422 already loaded
# [7602] User 6081362 already loaded
# [7603] User 42586896 already loaded
# [7604] User 18745193 already loaded
# [7605] User 2929765562 already loaded
# [7606] User 54799887 already loaded
# [7607] User 4774934117 already loaded
# [7608] User 280639137 already loaded
# [7609] User 745750589011812000 was added to queue (total count = 91)
# [7610] User 1398090512 already loaded
# [7611] User 2766677093 already loaded
# [7612] User 3042379841 already loaded
# [7613] User 269498302 already loaded
# [7614] User 20833706 already loaded
# [7615] User 2225798059 already loaded
# [7616] User 620451200 already loaded
# [7617] User 1701249770 already loaded
# [7618] User 1534819884 already loaded
# [7619] User 737854573637960000 was added to queue (total count = 92)
# [7620] User 25675733 already loaded
# [7621] User 3317174659 already loaded
# [7622] User 1004232505 already loaded
# [7623] User 4697688523 already loaded
# [7624] User 210869372 already loaded
# [7625] User 100047961 already loaded
# [7626] User 3406806707 already loaded
# [7627] User 1481190168 already loaded
# [7628] User 48386006 already loaded
# [7629] User 434695831 already loaded
# [7630] User 702665500472549000 was added to queue (total count = 93)
# [7631] User 2164245440 already loaded
# [7632] User 44332483 already loaded
# [7633] User 1619952294 already loaded
# [7634] User 2746260606 already loaded
# [7635] User 760239767627919000 was added to queue (total count = 94)
# [7636] User 1552810338 already loaded
# [7637] User 2216072416 already loaded
# [7638] User 46864848 already loaded
# [7639] User 3579398481 already loaded
# [7640] User 144321946 already loaded
# [7641] User 2949208994 already loaded
# [7642] User 3024496431 already loaded
# [7643] User 17564221 already loaded
# [7644] User 3321782792 already loaded
# [7645] User 2789738328 already loaded
# [7646] User 2253933161 already loaded
# [7647] User 163111324 already loaded
# [7648] User 384091493 already loaded
# [7649] User 633277953 already loaded
# [7650] User 2855946305 already loaded
# [7651] User 198264075 already loaded
# [7652] User 3385333011 already loaded
# [7653] User 2717785677 already loaded
# [7654] User 15745908 already loaded
# [7655] User 732212725129052000 was added to queue (total count = 95)
# [7656] User 756246889838748000 was added to queue (total count = 96)
# [7657] User 2745491150 already loaded
# [7658] User 33013647 already loaded
# [7659] User 286312318 already loaded
# [7660] User 2762740453 already loaded
# [7661] User 190055835 already loaded
# [7662] User 273128193 already loaded
# [7663] User 704490753 already loaded
# [7664] User 66951013 already loaded
# [7665] User 2388128191 already loaded
# [7666] User 490362948 already loaded
# [7667] User 18894618 already loaded
# [7668] User 108407072 already loaded
# [7669] User 4065131953 already loaded
# [7670] User 28992682 already loaded
# [7671] User 1539677432 already loaded
# [7672] User 2581586548 already loaded
# [7673] User 768294420 already loaded
# [7674] User 1278705324 already loaded
# [7675] User 21567649 already loaded
# [7676] User 508080349 already loaded
# [7677] User 469344128 already loaded
# [7678] User 162106726 already loaded
# [7679] User 3053986571 already loaded
# [7680] User 3269434189 already loaded
# [7681] User 2788368130 already loaded
# [7682] User 2652732326 already loaded
# [7683] User 549308820 already loaded
# [7684] User 3023290870 already loaded
# [7685] User 3071603159 already loaded
# [7686] User 263348660 already loaded
# [7687] User 2376564780 already loaded
# [7688] User 1516587925 already loaded
# [7689] User 712671618 already loaded
# [7690] User 731995571855102000 was added to queue (total count = 97)
# [7691] User 775023583 already loaded
# [7692] User 2881534905 was added to queue (total count = 98)
# [7693] User 4614204614 already loaded
# [7694] User 3185303798 already loaded
# [7695] User 21955296 already loaded
# [7696] User 87641130 already loaded
# [7697] User 2966360739 already loaded
# [7698] User 16222346 already loaded
# [7699] User 50343384 already loaded
# [7700] User 724921214 already loaded
# [7701] User 36350694 already loaded
# [7702] User 37113369 already loaded
# [7703] User 758009417111576000 was added to queue (total count = 99)
# [7704] User 758159125763195000 was added to queue (total count = 100)
# Getting users error
# Creating data frame from loaded data
# Merging data frame with the training set
# Finished building data frame

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# Для того, чтобы лучше понять, как устроена наша обучающая выборка, построим несколько графиков. Сначала построим долю "положительных" пользователей в зависимости от дня создания аккаунта. По горизонтальной оси отложим день создания аккаунта, а по вертикальной -- долю "положительных" пользователей ([подсказка](http://stroykova.github.io/sphera/l1_1.png)). Необходимо дописать код функции count_users. В функции необходимо посчитать пользователей в каждой группе (1 балл).

# %%
def count_users(grouped):
    dts = sort(list(set(map(lambda dt: dt if pd.notnull(dt) else "NA", df_full["created_at"]))))
    count_pos, count_neg = grouped.sum()['cls'], grouped.count()['cls'] - grouped.sum()['cls']
    return count_pos, count_neg, dts


grouped = df_full.groupby(map(lambda dt: dt if pd.notnull(dt) else "NA", df_full["created_at"]))
count_pos, count_neg, dts = count_users(grouped)
    
fraction_pos = count_pos / (count_pos + count_neg + 1e-10)
fraction_neg = 1 - fraction_pos

sort_ind = np.argsort(dts)
    
pl.figure(figsize=(20, 3))
pl.bar(np.arange(len(dts)), fraction_pos[sort_ind], width=1.0, color='red', alpha=0.6, linewidth=0, label="Positive")
pl.bar(np.arange(len(dts)), fraction_neg[sort_ind], bottom=fraction_pos[sort_ind], width=1.0, color='green', alpha=0.6, linewidth=0, label="Negative")
pl.xticks(np.arange(len(dts)) + 0.4, sorted(dts), rotation=90)
pl.title("Class distribution by account creation month")
pl.xlim(0, len(dts))
pl.legend()
pl.show()

# %% [markdown]
# Видно, что доля "положительных" аккаунтов в выборке растет с увеличением времени. Посмотрим, где живут пользователи положительной и отрицательной категории. Для этого отметим на карте каждого положительного пользователя красным, а отрицательного -- зеленым цветом ([подсказка](http://stroykova.github.io/sphera/l1_2.png)). Необходимо реализовать функцию plot_points_on_map. В функции необходимо отобразить на карте пользователей из разных классов (2 балла).

# %%
pl.figure(figsize=(20,12))

m = bm.Basemap(projection='cyl', llcrnrlat=-90, urcrnrlat=90, llcrnrlon=-180, urcrnrlon=180, resolution='c')

m.drawcountries(linewidth=0.2)
m.fillcontinents(color='lavender', lake_color='#000040')
m.drawmapboundary(linewidth=0.2, fill_color='#000040')
m.drawparallels(np.arange(-90,90,30),labels=[0,0,0,0], color='white', linewidth=0.5)
m.drawmeridians(np.arange(0,360,30),labels=[0,0,0,0], color='white', linewidth=0.5)

def plot_points_on_map(df_full):
    
    lat_positive = df_full[df_full['cls'] == 1][df_full['lat'].notnull()][df_full['lon'].notnull()]['lat']
    lon_positive = df_full[df_full['cls'] == 1][df_full['lat'].notnull()][df_full['lon'].notnull()]['lon']
    point = m.plot(lon_positive, lat_positive, 'ro', markersize=10)[0]
    
    lat_negative = df_full[df_full['cls'] == 0][df_full['lat'].notnull()][df_full['lon'].notnull()]['lat']
    lon_negative = df_full[df_full['cls'] == 0][df_full['lat'].notnull()][df_full['lon'].notnull()]['lon']
    point = m.plot(lon_negative, lat_negative, 'go', markersize=10)[0]
    
    return 

plot_points_on_map(df_full)

pl.title("Geospatial distribution of twitter users")
pl.legend()
pl.show()
# Out:
# /Users/anton/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/anton/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/anton/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/anton/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %% [markdown]
# В последней картинке есть проблема: сервис геоинформации определяет координаты с точностью до города, поэтому точки, соответствующте нескольким пользователям, могут накладываться. Предложите и реализуйте способ, позволяющий справиться с этой проблемой (2 балла).

# %% [markdown]
# В поле ниже необходимо словами описать, как было улучшено изображение (описание необходимо для корректной проверки задания).

# %% [markdown]
# На изображении сделаны следующие улучшения:
# * ...
# * ...

# %% [markdown]
# #### Опредилим пользователи какого класса популярнее, а именно пользователи какого класса имеют больше фолловеров.
#
# Для этого
#     1. Посчитайте дескриптивные статистики для признака followers_count -- min, max, mean и median
#     2. Постройте гистограммы для пользователей двух классов.
# [подсказка](http://stroykova.github.io/sphera/l1_3.png)
#     3. На основе полученных данных ответьте на вопросы
#         1. Почему mean и median имеют разные значения?
#             Медиана почти не учитывает единичные всплески, тогда как среднее даже от единичного всплеска может сильно поменяться. В даннм случае есть малое количество пользователей с очень большим количеством фоловеров, поэтому среднее сильно больше медианы
#         2. Пользователи какого класса популярнее? Аргументируйте ответ.
#             Пользователи негативного класса популярнее, это можно увидеть на примере тестовой выборки (и среднее и медиана у негативного класса больше) Так же по данным всей выборки среднее количество фоловеров у негативного класса больше
#
# Подсказка: так как пользователей позитивного класса в 3.5 раза больше, чем негативного прежде чем приступать к анализу необходимо случайным образом выбрать по N(N>=500) пользователей негативного и позитивного классов. (1 балл)

# %%
print "Negative mean ==", df_full[df_full["cls"]==0]['followers_count'].sum() / df_full[df_full["cls"]==0]['uid'].count()
print "Positive mean ==", df_full[df_full["cls"]==1]['followers_count'].sum() / df_full[df_full["cls"]==1]['uid'].count()
# Out:
# Negative mean == 2999.92583281
# Positive mean == 2737.4967903

# %%
sample_number = 500
users_wth_neg_class = df_full[df_full["cls"]==0].sample(sample_number)
users_wth_pos_class = df_full[df_full["cls"]==1].sample(sample_number)

def descriptive_stat_and_hist(users_wth_neg_class, users_wth_pos_class):
    
    print "Negative min ----- ", users_wth_neg_class[['followers_count']].min()[0]
    print "Negative max ----- ", users_wth_neg_class[['followers_count']].max()[0]
    print "Negative mean ---- ", users_wth_neg_class[['followers_count']].mean()[0]
    print "Negative median -- ", users_wth_neg_class[['followers_count']].median()[0]
    print ""
    print "Positive min ----- ", users_wth_pos_class[['followers_count']].min()[0]
    print "Positive max ----- ", users_wth_pos_class[['followers_count']].max()[0]
    print "Positive mean ---- ", users_wth_pos_class[['followers_count']].mean()[0]
    print "Positive median -- ", users_wth_pos_class[['followers_count']].median()[0]
    
    users_wth_neg_class[['followers_count']].hist()
    users_wth_pos_class[['followers_count']].hist()
    return

descriptive_stat_and_hist(users_wth_neg_class, users_wth_pos_class)
# Out:
# Negative min -----  2.0
# Negative max -----  590476.0
# Negative mean ----  4359.62903226
# Negative median --  412.0
#
# Positive min -----  1.0
# Positive max -----  578200.0
# Positive mean ----  3013.92943548
# Positive median --  382.0

# %% [markdown]
# Смотрим на полученный data frame и сохраняем его в .csv файл.

# %%
OUT_FILE_PATH = "hw1_out.csv"
print "Saving output data frame to %s" % OUT_FILE_PATH
df_full.to_csv(OUT_FILE_PATH, sep="\t", index=False, encoding="utf-8", quoting=csv.QUOTE_NONNUMERIC)
df_full.head()
# Out:
# Saving output data frame to hw1_out.csv
#           uid  cls               name    screen_name  \
# 0   202388889  1.0         Kim Salter   mustangkim11
# 1  1392518336  0.0       Tomboy Tarts    TomboyTarts
# 2   361208576  1.0      THE MANC GEEK       BigA85GL
# 3  1535215357  1.0                  L    laurynjiles
# 4  4396196375  1.0  #1stEdifyToUplift  EdifyToUplift
#
#                                          description verified  \
# 0             Author- Artist-Marvel-Cars-Books-Music    False
# 1  Celebrating the classic tomboy spirit with a b...    False
# 2  Mancunian geek, blogger/writer/reviewer. Consu...    False
# 3                            I'd rather be in Paris.    False
# 4  Awareness.Advocacy.Ascend🎈• Building awarenes...    False
#
#                   location       lat        lon         country created_at  \
# 0             Gulfport, FL  27.74836  -82.70343   United States    2010-10
# 1      Singapore/Malaysia    1.54860  103.52690        Malaysia    2013-04
# 2           Manchester, UK  53.48095   -2.23743  United Kingdom    2011-08
# 3             Marvel. DC.        NaN        NaN            None    2013-06
# 4  God is my refuge; gem❤️       NaN        NaN            None    2015-12
#
#    followers_count  friends_count  statuses_count  favourites_count  \
# 0           1052.0         1962.0          9481.0           21323.0
# 1           1195.0          837.0         19294.0            7184.0
# 2            632.0          577.0          7852.0            1141.0
# 3           2372.0         2436.0        187955.0           88086.0
# 4           1251.0          969.0         36809.0           27013.0
#
#    listed_count
# 0          29.0
# 1         110.0
# 2          29.0
# 3          70.0
# 4          96.0
